# %% [markdown]
# # Case Study - TCS, TATA MOTORS, TATA STEEL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [raw]
# historical data
# get stock market details of any company
# Comparison of different stocks (eg. TCS v/s WIPRO)
# Analyze graphs

# %%
infyDf = pd.read_csv('INFY.csv')
tcsDf = pd.read_csv('TCS.csv')

infyDf[['High', 'Low']].tail(10).plot()
tcsDf[['High', 'Low']].tail(10).plot()
# Out:
# <AxesSubplot:>

# %%
infyDf[['Date', 'High']].tail(10).plot()
# Out:
# <AxesSubplot:>
